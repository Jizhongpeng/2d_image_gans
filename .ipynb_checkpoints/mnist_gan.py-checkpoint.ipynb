# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# ERROR:root:Invalid alias: The name clear can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name more can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name less can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name man can't be aliased because it is another magic command.

# %%
import tensorflow as tf
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# Keras imports
import keras
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Conv2DTranspose, Flatten, Activation, LeakyReLU, Reshape, BatchNormalization
from keras.optimizers import RMSprop, Adam
import gc

# %%
# prevent tensorflow from using up all of the GPU's memory
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
# starting work on mnist branch.splitting the data into train/test. x = images, y = class 0-9;
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# display a sample of the mnist data
plt.figure(figsize=(5, 4))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()

# %%
# Input noise to generator
def noise_creator(num_of_samples, sample_size):
    return np.random.normal(loc=0, scale=1, size=(num_of_samples, sample_size))

# %%
# Generator function - take in one sample of random data
def generator(Z):
    # create a sequential model
    model = Sequential()
    
    # Input and layer 1
    model.add(Dense(784, input_shape = (100,)))
    model.add(Reshape(target_shape=(7,7,16)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))
    
    # Conv 1
    model.add(Conv2DTranspose(32,kernel_size=5, strides=2, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))
    
    # Conv 2
    model.add(Conv2DTranspose(1, kernel_size=5, strides=2, padding='same'))
    model.add(Activation('tanh'))
    
    # model name
    model.name='generator'
    
    # print the structure of the model
    print(model.summary())
    
    # output of the model
    return model

# %%
# discriminator - takes in an image, outputs probability that it is real or fake
def discriminator(X):
    # create a sequential model
    model = Sequential()
    
    # Conv 1
    model.add(Conv2D(32, kernel_size=5, strides=2, padding='same', input_shape = (28,28,1)))
    model.add(LeakyReLU(alpha=0.01))
    
    # Conv 2
    model.add(Conv2D(16, kernel_size=5, strides=2, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))
    
    # Fully-connected layer
    model.add(Flatten())
    model.add(Dense(784))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))
    
    
    # output
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    
    
    # model name 
    model.name='discriminator'
    
    # print the structure of the model
    print(model.summary())
    
    # output of the model
    return model

# %%
# setting whether the model can be trained (True) or not (False)
def set_training_status(model, status):
    for layer in model.layers:
        layer.trainable = status

# %%
# preprocessing function for the mnist data 
def preprocess(x):
    x = x.reshape(-1,28,28,1)
    x = np.float64(x)
    x = (x / 255 - 0.5) * 2
    x = np.clip(x, -1, 1)
    return x

# %%
# deprocessing function for viewing images
def deprocess(x):
    x = (x / 2 + 1) * 255
    x = np.clip(x, 0, 255)
    x = np.uint8(x)
    x = x.reshape(28, 28)
    return x

# %%
# deprocessing output test
deprocess_test = noise_creator(20,784)
deprocess_test = preprocess(deprocess_test)
plt.figure(figsize=(10,8))
for i in range(20):
    img = deprocess(deprocess_test[i])
    plt.subplot(4, 5, i+1)
    plt.imshow(img, cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
# creating labels for the data
def make_labels(rows):
    return np.random.uniform(low=0.0, high=0.1, size=(rows,1)), np.random.uniform(low=0.9, high=1.0, size=(rows,1))

# %%
# placeholder variables
Z_placeholder = K.placeholder(shape=(None,100))
X_placeholder = K.placeholder(shape=(28,28,1))

# declaring generator and discriminator
G_sample = generator(Z_placeholder)
D_sample = discriminator(X_placeholder)

# creating gan model with shared weights
gan = Sequential([
    G_sample,
    D_sample
])

gan.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 784)               79184
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 16)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 16)          64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 14, 14, 32)        12832
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 1)         801
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 93,009
# Trainable params: 92,913
# Non-trainable params: 96
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 16)          12816
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 16)          64
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               615440
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 784)               3136
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 785
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 633,073
# Trainable params: 631,473
# Non-trainable params: 1,600
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator (Sequential)       (None, 28, 28, 1)         93009
# _________________________________________________________________
# discriminator (Sequential)   (None, 1)                 633073
# =================================================================
# Total params: 726,082
# Trainable params: 724,386
# Non-trainable params: 1,696
# _________________________________________________________________

# %%
# %%capture cap --no-stdout

# hyper parameters
sample_size = 100
batch_size = 128
eval_size = 16
epochs = 100
g_learning_rate = 0.0001
d_learning_rate = 0.001
g_beta = 0.9
d_beta = 0.9

# compiling the model
D_sample.compile(optimizer=Adam(lr=d_learning_rate, beta_1=d_beta), loss='binary_crossentropy')
gan.compile(optimizer=Adam(lr=g_learning_rate, beta_1=g_beta), loss='binary_crossentropy')


# variables for data
x_train_processed = preprocess(x_train)
x_test_processed = preprocess(x_test)

y_train_real, y_train_fake = make_labels(batch_size)
y_eval_real,  y_eval_fake  = make_labels(eval_size)

losses = []

# training for-loop
for e in range(epochs):
    for i in range(len(x_train_processed)//batch_size):
        # the real mnist images
        x_batch_real = x_train_processed[i * batch_size: (i+1)*batch_size]
        
        # noise samples and corresponding images created by generator
        noise_samples = noise_creator(batch_size, sample_size)
        x_batch_fake = G_sample.predict_on_batch(noise_samples)
        
        # training the discriminator to detect real and fake images
        set_training_status(D_sample, True)
        D_sample.train_on_batch(x_batch_real, y_train_real)
        D_sample.train_on_batch(x_batch_fake, y_train_fake)
        
        # training the generator (using the combined gan model)
        set_training_status(D_sample, False)
        gan.train_on_batch(noise_samples, y_train_real)
        
    # evaluate
    x_eval_real = x_train_processed[np.random.choice(len(x_train_processed), eval_size, replace=False)]
    
    noise_samples = noise_creator(eval_size, sample_size)
    x_eval_fake = G_sample.predict_on_batch(noise_samples)
        
    d_loss = D_sample.test_on_batch(x_eval_real, y_eval_real)
    d_loss += D_sample.test_on_batch(x_eval_fake, y_eval_fake)
    g_loss = gan.test_on_batch(noise_samples, y_eval_real) # want fakes to be realistic
    
    losses.append((d_loss, g_loss))
    
    print("Epoch: {:>3}/{} Discriminator Loss: {:>6.4f} Generator Loss: {:>6.4f}".format(
        e+1, epochs, d_loss, g_loss))
# Out:
# Epoch:   1/100 Discriminator Loss: 3.1632 Generator Loss: 2.3812
# Epoch:   2/100 Discriminator Loss: 15.8253 Generator Loss: 15.1470
# Epoch:   3/100 Discriminator Loss: 11.8308 Generator Loss: 15.1470
# Epoch:   4/100 Discriminator Loss: 12.2061 Generator Loss: 15.1470
# Epoch:   5/100 Discriminator Loss: 7.7330 Generator Loss: 15.1470
# Epoch:   6/100 Discriminator Loss: 4.2628 Generator Loss: 3.5040
# Epoch:   7/100 Discriminator Loss: 4.8872 Generator Loss: 3.8754
# Epoch:   8/100 Discriminator Loss: 4.1534 Generator Loss: 3.7521
# Epoch:   9/100 Discriminator Loss: 5.1755 Generator Loss: 3.9361
# Epoch:  10/100 Discriminator Loss: 3.1535 Generator Loss: 3.5805
# Epoch:  11/100 Discriminator Loss: 3.5898 Generator Loss: 2.9511
# Epoch:  12/100 Discriminator Loss: 2.4903 Generator Loss: 0.4481
# Epoch:  13/100 Discriminator Loss: 1.9411 Generator Loss: 0.7220
# Epoch:  14/100 Discriminator Loss: 2.7114 Generator Loss: 0.6566
# Epoch:  15/100 Discriminator Loss: 2.6612 Generator Loss: 2.2017
# Epoch:  16/100 Discriminator Loss: 5.7293 Generator Loss: 5.1245
# Epoch:  17/100 Discriminator Loss: 3.0224 Generator Loss: 3.2293
# Epoch:  18/100 Discriminator Loss: 5.8638 Generator Loss: 6.5173
# Epoch:  19/100 Discriminator Loss: 2.6687 Generator Loss: 2.8319
# Epoch:  20/100 Discriminator Loss: 4.1278 Generator Loss: 4.0924
# Epoch:  21/100 Discriminator Loss: 5.8313 Generator Loss: 5.7213
# Epoch:  22/100 Discriminator Loss: 3.0652 Generator Loss: 3.3471
# Epoch:  23/100 Discriminator Loss: 5.4903 Generator Loss: 5.9301
# Epoch:  24/100 Discriminator Loss: 2.9067 Generator Loss: 3.1323
# Epoch:  25/100 Discriminator Loss: 4.1150 Generator Loss: 3.6906
# Epoch:  26/100 Discriminator Loss: 4.2106 Generator Loss: 4.7399
# Epoch:  27/100 Discriminator Loss: 2.7844 Generator Loss: 2.9678
# Epoch:  28/100 Discriminator Loss: 1.6659 Generator Loss: 2.1468
# Epoch:  29/100 Discriminator Loss: 5.8528 Generator Loss: 5.2252
# Epoch:  30/100 Discriminator Loss: 2.3236 Generator Loss: 3.0949
# Epoch:  31/100 Discriminator Loss: 2.5667 Generator Loss: 3.0198
# Epoch:  32/100 Discriminator Loss: 3.2562 Generator Loss: 3.3908
# Epoch:  33/100 Discriminator Loss: 2.1400 Generator Loss: 2.6274
# Epoch:  34/100 Discriminator Loss: 2.3364 Generator Loss: 3.1319
# Epoch:  35/100 Discriminator Loss: 2.7288 Generator Loss: 2.9275
# Epoch:  36/100 Discriminator Loss: 1.5894 Generator Loss: 1.5437
# Epoch:  37/100 Discriminator Loss: 1.4977 Generator Loss: 1.5153
# Epoch:  38/100 Discriminator Loss: 3.0413 Generator Loss: 3.1713
# Epoch:  39/100 Discriminator Loss: 1.6147 Generator Loss: 0.8608
# Epoch:  40/100 Discriminator Loss: 3.8677 Generator Loss: 5.1343
# Epoch:  41/100 Discriminator Loss: 3.5123 Generator Loss: 4.1885
# Epoch:  42/100 Discriminator Loss: 2.4350 Generator Loss: 2.5954
# Epoch:  43/100 Discriminator Loss: 1.6324 Generator Loss: 1.4048
# Epoch:  44/100 Discriminator Loss: 3.1867 Generator Loss: 3.2291
# Epoch:  45/100 Discriminator Loss: 3.5621 Generator Loss: 3.3304
# Epoch:  46/100 Discriminator Loss: 2.3263 Generator Loss: 3.0030
# Epoch:  47/100 Discriminator Loss: 3.8180 Generator Loss: 3.4228
# Epoch:  48/100 Discriminator Loss: 2.5114 Generator Loss: 2.4718
# Epoch:  49/100 Discriminator Loss: 2.1672 Generator Loss: 1.4871
# Epoch:  50/100 Discriminator Loss: 2.0994 Generator Loss: 1.6670
# Epoch:  51/100 Discriminator Loss: 3.9871 Generator Loss: 4.0230
# Epoch:  52/100 Discriminator Loss: 4.2626 Generator Loss: 4.5540
# Epoch:  53/100 Discriminator Loss: 3.1512 Generator Loss: 3.3543
# Epoch:  54/100 Discriminator Loss: 1.5492 Generator Loss: 0.5820
# Epoch:  55/100 Discriminator Loss: 2.1019 Generator Loss: 2.6346
# Epoch:  56/100 Discriminator Loss: 3.6922 Generator Loss: 3.6960
# Epoch:  57/100 Discriminator Loss: 6.1610 Generator Loss: 5.2743
# Epoch:  58/100 Discriminator Loss: 2.1949 Generator Loss: 2.2552
# Epoch:  59/100 Discriminator Loss: 1.8632 Generator Loss: 2.3870
# Epoch:  60/100 Discriminator Loss: 6.4767 Generator Loss: 6.5287
# Epoch:  61/100 Discriminator Loss: 1.3357 Generator Loss: 0.6709
# Epoch:  62/100 Discriminator Loss: 3.5352 Generator Loss: 3.4745
# Epoch:  63/100 Discriminator Loss: 1.9079 Generator Loss: 1.2166
# Epoch:  64/100 Discriminator Loss: 3.2212 Generator Loss: 3.9616
# Epoch:  65/100 Discriminator Loss: 4.3097 Generator Loss: 4.6736
# Epoch:  66/100 Discriminator Loss: 4.3361 Generator Loss: 5.2715
# Epoch:  67/100 Discriminator Loss: 5.8569 Generator Loss: 5.8451
# Epoch:  68/100 Discriminator Loss: 2.8529 Generator Loss: 2.6757
# Epoch:  69/100 Discriminator Loss: 1.9173 Generator Loss: 1.5255
# Epoch:  70/100 Discriminator Loss: 5.6432 Generator Loss: 5.3955
# Epoch:  71/100 Discriminator Loss: 3.6319 Generator Loss: 4.1150
# Epoch:  72/100 Discriminator Loss: 2.3958 Generator Loss: 1.9400
# Epoch:  73/100 Discriminator Loss: 1.7431 Generator Loss: 0.4954
# Epoch:  74/100 Discriminator Loss: 2.0047 Generator Loss: 1.9769
# Epoch:  75/100 Discriminator Loss: 3.8178 Generator Loss: 3.3537
# Epoch:  76/100 Discriminator Loss: 2.9806 Generator Loss: 3.2131
# Epoch:  77/100 Discriminator Loss: 4.0489 Generator Loss: 4.1710
# Epoch:  78/100 Discriminator Loss: 2.5952 Generator Loss: 3.2628
# Epoch:  79/100 Discriminator Loss: 3.1080 Generator Loss: 3.9998
# Epoch:  80/100 Discriminator Loss: 5.7223 Generator Loss: 5.9207
# Epoch:  81/100 Discriminator Loss: 3.1170 Generator Loss: 3.1700
# Epoch:  82/100 Discriminator Loss: 6.4378 Generator Loss: 6.8757
# Epoch:  83/100 Discriminator Loss: 5.1088 Generator Loss: 4.1937
# Epoch:  84/100 Discriminator Loss: 2.8546 Generator Loss: 2.9563
# Epoch:  85/100 Discriminator Loss: 3.7871 Generator Loss: 4.7809
# Epoch:  86/100 Discriminator Loss: 2.1196 Generator Loss: 2.6879
# Epoch:  87/100 Discriminator Loss: 2.8042 Generator Loss: 2.3288
# Epoch:  88/100 Discriminator Loss: 5.3710 Generator Loss: 6.0846
# Epoch:  89/100 Discriminator Loss: 2.2496 Generator Loss: 2.4265
# Epoch:  90/100 Discriminator Loss: 2.1838 Generator Loss: 2.8634
# Epoch:  91/100 Discriminator Loss: 5.6566 Generator Loss: 6.5523
# Epoch:  92/100 Discriminator Loss: 3.1251 Generator Loss: 3.4496
# Epoch:  93/100 Discriminator Loss: 1.6489 Generator Loss: 1.9782
# Epoch:  94/100 Discriminator Loss: 4.3356 Generator Loss: 4.5242
# Epoch:  95/100 Discriminator Loss: 4.4853 Generator Loss: 5.4204
# Epoch:  96/100 Discriminator Loss: 4.1900 Generator Loss: 4.1537
# Epoch:  97/100 Discriminator Loss: 2.3194 Generator Loss: 2.3487
# Epoch:  98/100 Discriminator Loss: 4.5685 Generator Loss: 4.9378
# Epoch:  99/100 Discriminator Loss: 2.0197 Generator Loss: 2.6572
# Epoch: 100/100 Discriminator Loss: 2.1415 Generator Loss: 1.6253

# %%
losses = np.array(losses)

fig, ax = plt.subplots()
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()
plt.show()

# %%
post_training_test = noise_creator(40,sample_size)
generated_digits = G_sample.predict(post_training_test)

plt.figure(figsize=(10, 8))
for i in range(20):
    img = deprocess(generated_digits[i])
    plt.subplot(4, 5, i+1)
    plt.imshow(img, cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()
#plt.savefig('2nd_gen.png')

# %%
# def get_gradients(model):
#     """Return the gradient of every trainable weight in model

#     Parameters
#     -----------
#     model : a keras model instance

#     First, find all tensors which are trainable in the model. Surprisingly,
#     `model.trainable_weights` will return tensors for which
#     trainable=False has been set on their layer (last time I checked), hence the extra check.
#     Next, get the gradients of the loss with respect to the weights.

#     """
#     weights = [tensor for tensor in model.trainable_weights if model.get_layer(tensor.name[:-2]).trainable]
#     optimizer = model.optimizer

#     return optimizer.get_gradients(model.total_loss, weights)

# %%
# gradients = np.array(gradients)
# print(gradients)

# # fig, ax = plt.subplots()
# # plt.plot(gradients.T[0], label='Discriminator')
# # plt.plot(gradients.T[1], label='Generator')
# # plt.title("Training Gradients")
# # plt.legend()
# # plt.show()

# %%
# Needs adaptation

# r_logits, r_rep = D_sample(X)
# f_logits, g_rep = D_Sample(G_sample,reuse=True)

# disc_loss = tef.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=r_logits,labels=tf.ones_like(r_logits)) + tf.nn.sigmoid_cross_entropy_with_logits(logits=f_logits,labels=tf.zeros_like(f_logits)))
# gen_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=f_logits,labels=tf.ones_like(f_logits)))

# %%
# gen_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope="GAN/Generator")
# disc_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope="GAN/Discriminator")

# gen_step = tf.train.RMSPropOptimizer(learning_rate=0.001).minimize(gen_loss,var_list = gen_vars) # G Train step
# disc_step = tf.train.RMSPropOptimizer(learning_rate=0.001).minimize(disc_loss,var_list = disc_vars) # D Train step

# sess = tf.Session(config=config)
# sess = tf.Session()
# tf.global_variables_initializer().run(session=sess)

# batch_size = 256
# nd_steps = 10
# ng_steps = 10

# x_plot = sample_data(n=batch_size)

# f = open('loss_logs.csv','w')
# f.write('Iteration,Discriminator Loss,Generator Loss\n')

# %%
# for i in range(10001):
#     X_batch = sample_data(n=batch_size)
    
#     # 28 x 28 pixel images
#     Z_batch = sample_Z(batch_size, 28, 28)

#     for _ in range(nd_steps):
#         _, dloss = sess.run([disc_step, disc_loss], feed_dict={X: X_batch, Z: Z_batch})
#     rrep_dstep, grep_dstep = sess.run([r_rep, g_rep], feed_dict={X: X_batch, Z: Z_batch})

#     for _ in range(ng_steps):
#         _, gloss = sess.run([gen_step, gen_loss], feed_dict={Z: Z_batch})

#     rrep_gstep, grep_gstep = sess.run([r_rep, g_rep], feed_dict={X: X_batch, Z: Z_batch})

#     print("Iterations: %d\t Discriminator loss: %.4f\t Generator loss: %.4f" % (i,dloss,gloss))
#     if i%10 == 0:
#         f.write("%d,%f,%f\n"%(i,dloss,gloss))

#     if i%1000 == 0:
#         # Iterations gif
#         plt.figure()
#         g_plot = sess.run(G_sample, feed_dict={Z: Z_batch})
#         xax = plt.scatter(x_plot[:,0], x_plot[:,1])
#         gax = plt.scatter(g_plot[:,0],g_plot[:,1])
#         plt.xlim(-60, 60)
#         plt.ylim(-50, 2600)
#         plt.legend((xax,gax), ("Real Data","Generated Data"))
#         plt.title('Samples at Iteration %d'%i)
#         plt.tight_layout()
#         plt.savefig('../plots/iterations/iteration_%d.png'%i)
#         plt.close()

#         # Feature transform gif
#         plt.figure()
#         rrd = plt.scatter(rrep_dstep[:,0], rrep_dstep[:,1], alpha=0.5)
#         rrg = plt.scatter(rrep_gstep[:,0], rrep_gstep[:,1], alpha=0.5)
#         grd = plt.scatter(grep_dstep[:,0], grep_dstep[:,1], alpha=0.5)
#         grg = plt.scatter(grep_gstep[:,0], grep_gstep[:,1], alpha=0.5)
#         plt.xlim(-200, 200)
#         plt.ylim(-40, 40)
#         plt.legend((rrd, rrg, grd, grg), ("Real Data Before G step","Real Data After G step",
#                                "Generated Data Before G step","Generated Data After G step"))
#         plt.title('Transformed Features at Iteration %d'%i)
#         plt.tight_layout()
#         plt.savefig('../plots/features/feature_transform_%d.png'%i)
#         plt.close()

#         # Feature transform of centroids gif
#         plt.figure()
#         rrdc = plt.scatter(np.mean(rrep_dstep[:,0]), np.mean(rrep_dstep[:,1]),s=100, alpha=0.5)
#         rrgc = plt.scatter(np.mean(rrep_gstep[:,0]), np.mean(rrep_gstep[:,1]),s=100, alpha=0.5)
#         grdc = plt.scatter(np.mean(grep_dstep[:,0]), np.mean(grep_dstep[:,1]),s=100, alpha=0.5)
#         grgc = plt.scatter(np.mean(grep_gstep[:,0]), np.mean(grep_gstep[:,1]),s=100, alpha=0.5)
#         plt.xlim(-50, 50)
#         plt.ylim(-50, 50)
#         plt.legend((rrdc, rrgc, grdc, grgc), ("Real Data Before G step","Real Data After G step",
#                                "Generated Data Before G step","Generated Data After G step"))

#         plt.title('Centroid of Transformed Features at Iteration %d'%i)
#         plt.tight_layout()
#         plt.savefig('../plots/features/feature_transform_centroid_%d.png'%i)
#         plt.close()

# f.close()
